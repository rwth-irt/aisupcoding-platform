# %% [markdown]
# # KI–Tutor für die Veranstaltung „Maschinelles Lernen in der industriellen Regelungstechnik“
#
# ## Disclaimer zur Nutzung des KI-Tools in der Lehrveranstaltung
# Dieses KI-Tool wird im Rahmen der Lehrveranstaltung zu **Lehr- und Lernzwecken** eingesetzt.
# Bitte beachten Sie, dass die vom Tool bereitgestellten Inhalte **automatisiert** durch *künstliche Intelligenz* generiert werden.
#
# **Wichtig:** Es kann keine Gewähr für **Richtigkeit**, **Vollständigkeit** oder **Aktualität** der Ergebnisse übernommen werden.
# Die Nutzung erfolgt auf **eigene Verantwortung**.
#
# ---
#
# ## Datenschutz
# Im Rahmen der Nutzung werden ausschließlich **anonymisierte Daten** gespeichert.
# Es erfolgt **keine Erfassung oder Speicherung personenbezogener Daten**.
#
# Alle Eingaben und Ausgaben werden ausschließlich zur **Verbesserung der Lehr- und Lernqualität** verwendet und lassen keine Rückschlüsse auf einzelne Nutzerinnen oder Nutzer zu.
#
# *Mit der Nutzung des Tools erklären Sie sich mit diesen Bedingungen einverstanden.*

# %%
from IPython.display import HTML, display

display(HTML("""
<style>
div.input { display: none; }
</style>

<script>
(function() {
  function lockAllCodeCells() {
    if (!window.Jupyter || !Jupyter.notebook) return;
    var ncells = Jupyter.notebook.ncells();
    for (var i = 0; i < ncells; i++) {
      var cell = Jupyter.notebook.get_cell(i);
      if (cell && cell.cell_type === 'code') {
        cell.code_mirror.setOption('readOnly', 'nocursor');
      }
    }
  }
  lockAllCodeCells();
  setTimeout(lockAllCodeCells, 300);
  setTimeout(lockAllCodeCells, 1000);
})();
</script>
"""))




import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from python_interface.ui_kitutor import show
show()
# Out:
# <style>
# div.input { display: none; }
# </style>
#
# <script>
# (function() {
#   function lockAllCodeCells() {
#     if (!window.Jupyter || !Jupyter.notebook) return;
#     var ncells = Jupyter.notebook.ncells();
#     for (var i = 0; i < ncells; i++) {
#       var cell = Jupyter.notebook.get_cell(i);
#       if (cell && cell.cell_type === 'code') {
#         cell.code_mirror.setOption('readOnly', 'nocursor');
#       }
#     }
#   }
#   lockAllCodeCells();
#   setTimeout(lockAllCodeCells, 300);
#   setTimeout(lockAllCodeCells, 1000);
# })();
# </script>
# ...
